# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vectorstore = Chroma(
    embedding_function=OpenAIEmbeddings(),
    collection_name="ipl_players",
    persist_directory="./chroma_db"
)

# %%
vectorstore.add_documents(docs)
# Out:
# ['f55b6acd-dadb-41d5-b644-bf08d505fc53',
#  'd0576e2a-a260-4356-8cdc-82e941a0daec',
#  '19f87506-e76d-4c67-8e08-4bafc40bb618',
#  'a52431cd-212e-4d13-bee1-94f22a1edfde',
#  '9fd4bc32-fe84-421d-8d29-2385b23b19a4']

# %%
# view documents
vectorstore.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['f55b6acd-dadb-41d5-b644-bf08d505fc53',
#   'd0576e2a-a260-4356-8cdc-82e941a0daec',
#   '19f87506-e76d-4c67-8e08-4bafc40bb618',
#   'a52431cd-212e-4d13-bee1-94f22a1edfde',
#   '9fd4bc32-fe84-421d-8d29-2385b23b19a4'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
# ...

# %%
vectorstore.similarity_search_with_score(
    query = "Which players are good at finishing matches?", 
    k=2
)
# Out:
# [(Document(id='19f87506-e76d-4c67-8e08-4bafc40bb618', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.4267114996910095),
#  (Document(id='f55b6acd-dadb-41d5-b644-bf08d505fc53', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'),
#   0.47464847564697266)]

# %%
# metadata with filter
vectorstore.similarity_search_with_score(
    query = "Which players are good at finishing matches?",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='19f87506-e76d-4c67-8e08-4bafc40bb618', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.426533579826355),
#  (Document(id='9fd4bc32-fe84-421d-8d29-2385b23b19a4', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.47652292251586914)]

# %%
# update documents
doc_update = Document(
    page_content="MS Dhoni is a legendary finisher in cricket, known for his calm demeanor and ability to finish matches under pressure. He has led Chennai Super Kings to multiple IPL titles.",
    metadata={"team": "Chennai Super Kings"}
)

vectorstore.update_document(document_id = '19f87506-e76d-4c67-8e08-4bafc40bb618', document=doc_update)

vectorstore.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['f55b6acd-dadb-41d5-b644-bf08d505fc53',
#   'd0576e2a-a260-4356-8cdc-82e941a0daec',
#   '19f87506-e76d-4c67-8e08-4bafc40bb618',
#   'a52431cd-212e-4d13-bee1-94f22a1edfde',
#   '9fd4bc32-fe84-421d-8d29-2385b23b19a4'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [-0.00612549,  0.00927136,  0.01047755, ..., -0.0292615 ,
#           0.01667801, -0.00263895],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
# ...
